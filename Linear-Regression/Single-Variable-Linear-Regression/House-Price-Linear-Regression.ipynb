# %%
# %pip install pandas
# %pip install matplotlib
# %pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./house-prices.csv")
df.head(5)
# Out:
#    Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0     1  114300  1790         2          2       2    No         East
# 1     2  114200  2030         4          2       3    No         East
# 2     3  114800  1740         3          2       1    No         East
# 3     4   94700  1980         3          2       3    No         East
# 4     5  119800  2130         3          3       3    No         East

# %%
model = LinearRegression()
model.fit(df[['SqFt']],df.Price) # giving x(in the form of 2D array) and y variables
# Out:
# LinearRegression()

# %%
model.predict([[5000]])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([341040.4613053])

# %%
model.coef_
# Out:
# array([70.22631824])

# %%
model.intercept_
# Out:
# -10091.129909123061

# %%
# by using the train_test_split method
x = df[["SqFt"]]
y = df.Price
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
model.predict(x_test)
# Out:
# array([119125.29565779, 112102.6638335 , 132468.29612393, 124743.40111722,
#        124041.13793479, 112102.6638335 , 159856.56023866, 125445.66429965,
#        161261.08660352, 102973.24246192, 135979.61203608, 145109.03340765,
#        126850.1906645 , 124743.40111722, 131063.76975908, 110698.13746864,
#        125445.66429965, 138086.40158336, 134575.08567122, 133170.55930636,
#        147215.82295494, 124041.13793479, 122636.61156993, 109293.61110378,
#        109995.87428621, 141597.71749551])

# %%
# for y = m * x + b where m = slope and b = intercept
70.22631824 * 5000 + -10091.129909123061
# Out:
# 341040.4612908769

# %%
plt.xlabel('SqFt')
plt.ylabel('Price')
plt.title('SqFt vs Price')
plt.scatter(x, y, color='black', marker = '*')

# %%
plt.xlabel('SqFt')
plt.ylabel('Price')
plt.title('SqFt vs Price')
plt.scatter(x, y, color='black', marker = '*')
plt.plot(df.SqFt, model.predict(df[['SqFt']]), color = 'red')
